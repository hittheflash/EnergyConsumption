# %%
# %cd /content/drive/MyDrive/_main_/1_FL/data_energy/datalog
# Out:
# /content/drive/MyDrive/_main_/1_FL/data_energy/datalog

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import tensorflow as tf ### AI
# import sklearn

import json
from glob import glob

# %%
glob("*json")
# Out:
# ['ventilador_on.json',
#  'lampara_on.json',
#  'congelador_on.json',
#  'congelador_v1.json',
#  'lampara_v1.json',
#  'ventilador_v1.json']

# %%
def get_data(lista_j):
    datas_x1 = pd.DataFrame(lista_j)
    datas_x2 = pd.DataFrame([i['data'] for i in lista_j])
    datas = pd.concat([datas_x1, datas_x2], axis=1).drop(columns=['data'])
    datas['fechaCreacion'] = datas['fechaCreacion'].astype('datetime64[ms]')
    datas = datas.sort_values('fechaCreacion')
    datas.index = datas['fechaCreacion']
    # datas = datas.resample('1min').sum()
    datas = datas.resample('1min').mean()
    # return datas.drop(columns=['idLog', 'idSensor'])[['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf', 'fechaCreacion']]
    # return datas[['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf', 'fechaCreacion']]
    return datas[['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf']]

# %% [markdown]
# ### 1era muestra

# %%
ventilador = json.load(open('ventilador_on.json'))
lampara = json.load(open('lampara_on.json'))
congelador = json.load(open('congelador_on.json'))

# %%
df_v = get_data(ventilador)
print("vantilador", df_v.shape)
df_l = get_data(lampara)
print("lampara", df_l.shape)
df_c = get_data(congelador)
print("congelador", df_c.shape)
# Out:
# vantilador (165, 7)
# lampara (171, 7)
# congelador (194, 7)

# %%
df_v
# Out:
#                      corriente     voltaje   potencia  potencia_efectiva  \
# fechaCreacion
# 2022-07-01 18:28:00       0.44  120.133333  52.858667          51.433333
# 2022-07-01 18:29:00        NaN         NaN        NaN                NaN
# 2022-07-01 18:30:00        NaN         NaN        NaN                NaN
# 2022-07-01 18:31:00        NaN         NaN        NaN                NaN
# 2022-07-01 18:32:00        NaN         NaN        NaN                NaN
# ...                        ...         ...        ...                ...
# 2022-07-01 21:08:00       0.44  120.014286  52.806286          51.450000
# 2022-07-01 21:09:00       0.44  119.613333  52.629867          51.080000
# 2022-07-01 21:10:00       0.44  119.686667  52.662133          51.160000
# 2022-07-01 21:11:00       0.44  119.700000  52.668000          51.173333
# 2022-07-01 21:12:00       0.44  119.688889  52.663111          51.166667
#
#                      energia  frecuencia        pf
# fechaCreacion
# ...

# %%
plt.style.available

# %%
tweepy

# %%
# movilizacionnacional2022

# %%
plt.style.use?

# %%
plt.style.use('seaborn')
# plt.style.use('tableau-colorblind10')
# plt.style.use('seaborn-poster')

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24, 7))
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(25, 12))

# atributos = ['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf']
# atributos = ['potencia', 'potencia_efectiva']
atributos = ['potencia', 'potencia_efectiva', 'voltaje', 'frecuencia']
atributos2 = ['corriente', 'energia', 'pf']

ax1.plot(df_v[atributos])
ax1.legend(atributos)
ax1.set_title('Ventilador')
ax1.grid()

ax2.plot(df_l[atributos])
ax2.legend(atributos)
ax2.set_title('Lampara')
ax2.grid()

ax3.plot(df_c[atributos])
ax3.legend(atributos)
ax3.set_title('Congelador')
ax3.grid()

# %%
model.predict(
    [3, 4, 4, 3]
)

# %%
[0.98, 0.01, 0.01] ###

# %%
{
    'ventidador':0.98,
    'congelador':0.1,
    'lampara':0.01
}

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24, 7))
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(25, 12))

# atributos = ['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf']
atributos = ['potencia', 'potencia_efectiva']
atributos2 = ['corriente', 'energia', 'pf']

ax1.plot(df_v[atributos2])
ax1.legend(atributos2)
ax1.set_title('Ventilador')
ax1.grid()

ax2.plot(df_l[atributos2])
ax2.legend(atributos2)
ax2.set_title('Lampara')
ax2.grid()

ax3.plot(df_c[atributos2])
ax3.legend(atributos2)
ax3.set_title('Congelador')
ax3.grid() ### porcentaje => pf

# %%
df_c.energia.plot()

# %%
df_c2.iloc[:-2].energia.plot()

# %%
df_v.drop(columns=['voltaje', 'frecuencia']).hist(figsize=(10, 10), bins=50, xlabelsize=8, ylabelsize=8)
plt.show()

# %%
df_l.drop(columns=['voltaje', 'frecuencia']).hist(figsize=(10, 10), bins=50, xlabelsize=8, ylabelsize=8)
plt.show()

# %%
df_c.drop(columns=['voltaje', 'frecuencia']).hist(figsize=(10, 10), bins=50, xlabelsize=8, ylabelsize=8)
plt.show()

# %%
df_v.head(3)
# Out:
#                      corriente     voltaje   potencia  potencia_efectiva  \
# fechaCreacion
# 2022-07-01 18:28:00       0.44  120.133333  52.858667          51.433333
# 2022-07-01 18:29:00        NaN         NaN        NaN                NaN
# 2022-07-01 18:30:00        NaN         NaN        NaN                NaN
#
#                      energia  frecuencia        pf
# fechaCreacion
# 2022-07-01 18:28:00     0.86   59.966667  0.966667
# 2022-07-01 18:29:00      NaN         NaN       NaN
# 2022-07-01 18:30:00      NaN         NaN       NaN

# %%
df_l.head(3)
# Out:
#                      corriente     voltaje  potencia  potencia_efectiva  \
# fechaCreacion
# 2022-06-30 22:37:00       0.09  121.100000   10.8990             4.8625
# 2022-06-30 22:38:00       0.09  119.906667   10.7916             4.8800
# 2022-06-30 22:39:00       0.09  121.506667   10.9356             4.8800
#
#                      energia  frecuencia        pf
# fechaCreacion
# 2022-06-30 22:37:00     0.19     59.9625  0.453750
# 2022-06-30 22:38:00     0.19     59.9800  0.460000
# 2022-06-30 22:39:00     0.19     59.9800  0.456667

# %%
df_c.head(3)
# Out:
#                      corriente     voltaje    potencia  potencia_efectiva  \
# fechaCreacion
# 2022-07-03 06:11:00   2.156667  123.433333  266.204556         168.211111
# 2022-07-03 06:12:00   2.121333  123.266667  261.489867         161.713333
# 2022-07-03 06:13:00   2.107333  123.180000  259.581400         159.226667
#
#                       energia  frecuencia        pf
# fechaCreacion
# 2022-07-03 06:11:00  1.000000   59.933333  0.633333
# 2022-07-03 06:12:00  1.003333   59.960000  0.620667
# 2022-07-03 06:13:00  1.010000   59.953333  0.611333

# %%
df_v.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 165 entries, 2022-07-01 18:28:00 to 2022-07-01 21:12:00
# Freq: T
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   corriente          159 non-null    float64
#  1   voltaje            159 non-null    float64
#  2   potencia           159 non-null    float64
#  3   potencia_efectiva  159 non-null    float64
#  4   energia            159 non-null    float64
#  5   frecuencia         159 non-null    float64
#  6   pf                 159 non-null    float64
# dtypes: float64(7)
# memory usage: 10.3 KB

# %% [markdown]
# ### 2DA MUESTRA

# %%
glob("*v1*json")
# Out:
# ['congelador_v1.json', 'lampara_v1.json', 'ventilador_v1.json']

# %%
ventilador_2 = json.load(open('ventilador_v1.json'))
lampara_2 = json.load(open('lampara_v1.json'))
congelador_2 = json.load(open('congelador_v1.json'))

# %%
# df_c2.iloc[:-2]

# %%
df_v2 = get_data(ventilador_2)
print("vantilador", df_v2.shape)
df_l2 = get_data(lampara_2)
print("lampara", df_l2.shape)
df_c2 = get_data(congelador_2).iloc[:-2]
print("congelador", df_c2.shape)
# Out:
# vantilador (277, 7)
# lampara (151, 7)
# congelador (981, 7)

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24, 7))
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(25, 12))

# atributos = ['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf']
# atributos = ['potencia', 'potencia_efectiva']
atributos = ['potencia', 'potencia_efectiva', 'voltaje', 'frecuencia']
atributos2 = ['corriente', 'energia', 'pf']

ax1.plot(df_v2[atributos])
ax1.legend(atributos)
ax1.set_title('Ventilador')
ax1.grid()

ax2.plot(df_l2[atributos])
ax2.legend(atributos)
ax2.set_title('Lampara')
ax2.grid()

ax3.plot(df_c2[atributos])
ax3.legend(atributos)
ax3.set_title('Congelador')
ax3.grid()

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, sharey=True, figsize=(24, 7))
# fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=True, figsize=(25, 12))

# atributos = ['corriente', 'voltaje', 'potencia', 'potencia_efectiva', 'energia', 'frecuencia', 'pf']
atributos = ['potencia', 'potencia_efectiva']
atributos2 = ['corriente', 'energia', 'pf']

ax1.plot(df_v2[atributos2])
ax1.legend(atributos2)
ax1.set_title('Ventilador')
ax1.grid()

ax2.plot(df_l2[atributos2])
ax2.legend(atributos2)
ax2.set_title('Lampara')
ax2.grid()

ax3.plot(df_c2[atributos2])
ax3.legend(atributos2)
ax3.set_title('Congelador')
ax3.grid()

# %%
df_v2.drop(columns=['voltaje', 'frecuencia']).hist(figsize=(10, 10), bins=50, xlabelsize=8, ylabelsize=8)
plt.show()

# %%
df_l2.drop(columns=['voltaje', 'frecuencia']).hist(figsize=(10, 10), bins=50, xlabelsize=8, ylabelsize=8)
plt.show()

# %%
df_c2.drop(columns=['voltaje', 'frecuencia']).hist(figsize=(10, 10), bins=50, xlabelsize=8, ylabelsize=8)
plt.show()

# %%
df_v2.drop(columns=['voltaje', 'frecuencia'])
# Out:
#                      corriente   potencia  potencia_efectiva   energia  \
# fechaCreacion
# 2022-07-05 17:14:00   0.440000  52.415000          50.775000  1.370000
# 2022-07-05 17:15:00   0.377143  44.917714          43.500000  1.174286
# 2022-07-05 17:16:00   0.440000  52.374667          50.733333  1.370000
# 2022-07-05 17:17:00   0.440000  52.430400          50.820000  1.370000
# 2022-07-05 17:18:00   0.440000  52.589429          51.007143  1.370000
# ...                        ...        ...                ...       ...
# 2022-07-05 21:46:00   0.448667  54.681600          52.706667  1.600000
# 2022-07-05 21:47:00   0.448667  54.567600          52.486667  1.600000
# 2022-07-05 21:48:00   0.450000  54.705000          52.493333  1.600000
# 2022-07-05 21:49:00   0.447857  54.192571          52.092857  1.600000
# 2022-07-05 21:50:00   0.450000  54.562500          52.200000  1.600000
#
#                            pf
# fechaCreacion
# 2022-07-05 17:14:00  0.965000
# ...
